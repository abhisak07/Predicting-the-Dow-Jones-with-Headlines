# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisak07/Predicting-the-Dow-Jones-with-Headlines/blob/master/COMPLETE_facebook_model_blender_90m_and_27b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/ParlAI.git
# Out:
# Cloning into 'ParlAI'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 30183 (delta 63), reused 56 (delta 31), pack-reused 30059
# Receiving objects: 100% (30183/30183), 58.51 MiB | 44.61 MiB/s, done.
# Resolving deltas: 100% (21458/21458), done.

# %%
cd /content/ParlAI
# Out:
# /content/ParlAI

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/parlai.egg-link (link to .)
# Adding parlai 0.1.20200503 to easy-install.pth file
#
# Installed /content/ParlAI
# Processing dependencies for parlai==0.1.20200503
# Searching for websocket-server==0.4
# Reading https://pypi.org/simple/websocket-server/
# ...
# Best match: websocket-server 0.4
# Processing websocket_server-0.4.tar.gz
# Writing /tmp/easy_install-r530z2ao/websocket_server-0.4/setup.cfg
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 133kB 3.1MB/s
# ...
#      |████████████████████████████████| 5.7MB 26.5MB/s
# ...
#      |████████████████████████████████| 552kB 61.4MB/s
# ...
#      |████████████████████████████████| 1.5MB 61.4MB/s
# ...
#      |████████████████████████████████| 235kB 61.0MB/s
# ...
#      |████████████████████████████████| 61kB 8.9MB/s
# ...
#      |████████████████████████████████| 276kB 61.3MB/s
# ...
#      |████████████████████████████████| 1.1MB 12.1MB/s
# ...
#      |████████████████████████████████| 655kB 60.6MB/s
# ...
#      |████████████████████████████████| 61kB 8.8MB/s
# ...
#      |████████████████████████████████| 3.3MB 60.4MB/s
# ...
#      |████████████████████████████████| 61kB 9.2MB/s
# ...
#      |████████████████████████████████| 71kB 9.4MB/s
# ...
#      |████████████████████████████████| 81kB 10.5MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449905 sha256=e5f209933d677586bb3c0ba2c9e12bafa88940d05498d3efc9fc42358318697d
# ...

# %%
#inATll pytorch
pip install torch===1.5.0 torchvision===0.6.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 752.0MB 19kB/s
# ...
#      |████████████████████████████████| 6.6MB 44.6MB/s
# ...
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# ...

# %%
#"""before that we have to install pip install 'git+https://github.com/rsennrich/subword-nmt.git#egg=subword-nmt other with will throush aerror"""
# !pip install subword-nmt

# %%
#now test Chatting with the models, 90M model normal
# !python parlai/scripts/safe_interactive.py -t blended_skill_talk -mf zoo:blender/blender_90M/model
# Out:
# [ warning: overriding opt['task'] to blended_skill_talk (previously: internal:blended_skill_talk,wizard_of_wikipedia,convai2,empathetic_dialogues )]
# [ warning: overriding opt['model_file'] to /content/ParlAI/data/models/blender/blender_90M/model (previously: /checkpoint/edinan/20200210/baseline_BST_retnref/lr=7.5e-06_attention-dropout=0.0_relu-dropout=0.0/model )]
# Dictionary: loading dictionary from /content/ParlAI/data/models/blender/blender_90M/model.dict
# [ num words =  54944 ]
# [TransformerGenerator: full interactive mode on.]
# Total parameters: 87,508,992 (87,508,992 trainable)
# [ Loading existing model params from /content/ParlAI/data/models/blender/blender_90M/model ]
# [ optional arguments: ]
# [  display_examples: False ]
# [  display_ignore_fields: label_candidates,text_candidates ]
# [  display_prettify: False ]
# [  interactive_task: True ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 16 ]
# [  datapath: /content/ParlAI/data ]
# [  datatype: train ]
# ...

# %%
#now test Chatting with the models, 2.7B model normal
# !python parlai/scripts/safe_interactive.py -t blended_skill_talk -mf zoo:blender/blender_3B/model
# Out:
#                                  /@&%###%&&@@#
#                       .,*/((((##@@@&%%#%%&&@@@&%%#/*.
#              #@@&&&%%%%##(((///*****//(((###%%%&&&@@@@@&&%#%%#.
#          .%&@@@@@&&&%%%####((((////((((####%%%&&&@@@@@&&%%#%%####,
#            ./,,#(//**,,.....,,,,***////((((########%%%%%%%%###(((
#               /*(//**,,,....,,,,***////((((########%%%%%%%%###(#%*
#                (*,...      ...,,,***//////((((((///////(/*...,/#@@@(
#                **,,..         ...,,,,,,,,,,........,,*///*...*(#@@@@&&*
#                ./,,..          ...,,,,,,,,,........,,*//*,...*#/,,,,,/%#
#                 (*,..          ...,,,,,,,,,........,,*//*,..,/(      .,#(
#                 **,..          ...,,,,,,,,,.........,*//*,..,((       .,(#
#                  /*,..          ....,,,,,,,.....  ..,***,,,,(#         ..#&
#                  **,..          ....,,,,,,,....   ..,***,,,*#.         .,%@
#                  ./,...          B L E N D E R    ...***,,,*#          .*%@
# ...

# %%
#allocate more ram in google colab run this command
d=[]
while(1):
  d.append('1')

# %%
cd /content/ParlAI/data/OffensiveLanguage
# Out:
# /content/ParlAI/data/OffensiveLanguage

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d9b138e-8576-469f-a2c8-909946f8051f" name="files[]" multiple disabled />
#      <output id="result-4d9b138e-8576-469f-a2c8-909946f8051f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
cd /content/ParlAI/data

# %%
# !zip -r /content/ParlAI/data.zip /content/ParlAI/data
# Out:
#   adding: content/ParlAI/data/ (stored 0%)
#   adding: content/ParlAI/data/blended_skill_talk/ (stored 0%)
#   adding: content/ParlAI/data/blended_skill_talk/valid.json (deflated 64%)
#   adding: content/ParlAI/data/blended_skill_talk/topic_to_persona_list.txt (deflated 65%)
#   adding: content/ParlAI/data/blended_skill_talk/persona_list.txt (deflated 77%)
#   adding: content/ParlAI/data/blended_skill_talk/train.txt (deflated 73%)
#   adding: content/ParlAI/data/blended_skill_talk/valid.txt (deflated 64%)
#   adding: content/ParlAI/data/blended_skill_talk/train.json (deflated 71%)
#   adding: content/ParlAI/data/blended_skill_talk/test.txt (deflated 64%)
#   adding: content/ParlAI/data/blended_skill_talk/.built (stored 0%)
#   adding: content/ParlAI/data/blended_skill_talk/test.json (deflated 64%)
#   adding: content/ParlAI/data/OffensiveLanguage/ (stored 0%)
#   adding: content/ParlAI/data/OffensiveLanguage/OffensiveLanguage.txt (deflated 51%)
# ...
